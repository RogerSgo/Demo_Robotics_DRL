# %%
import gymnasium 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import DemoC_RL # entorno
import stable_baselines3
from stable_baselines3.common.env_checker import check_env # verificar el entorno

ENV_NAME = "DemoC_RL/TareaRL-v0"
env = gymnasium.make(ENV_NAME) 
#check_env(env, warn=True) # si funciona
# Out:
# Conectado al servidor API remoto

# %%
print("Espacio de observacion:", env.observation_space)
print("Shape Obs:", env.observation_space.shape) 
print("tipo de observacion:", env.observation_space.dtype) 
print("Sample Obs:", env.observation_space.sample())
print("Espacio de accion:", env.action_space)
#print(env.get_imagen())
print("Action space sample:", env.action_space.sample())
#print("Estado:", env.vector_estado())
# Out:
# Espacio de observacion: Box(-1.0, 1.0, (3,), float32)
# Shape Obs: (3,)
# tipo de observacion: float32
# Sample Obs: [0.8019446  0.44318274 0.3043833 ]
# Espacio de accion: Box(-1.0, 1.0, (3,), float32)
# Action space sample: [ 0.03450142 -0.5367197   0.35433018]

# %%
# Evaluar sistema con acciones aleatorias
acc=[]
X_ = []
Y_ = []
reward_points = 0#init_reward_points()

for episode in range(10):
    env.reset()
    #print(f'Episodio: {episode}')
    for step in range(10):
        env.render()
        env.step(env.action_space.sample())   # toma una accion aleatoria
        #time.sleep(5)
        reward = 0   #env.compute_reward(env.compute_distance(env.init_reward_points()))
        acc += [reward]
        X_.append(episode)
        Y_.append(np.array(acc).mean())
       
        print('Reecompensa Actual: {0:.3f}'.format(reward))
        #draw_rl_debug(env.step(env.action_space.sample()), reward_points)
    
plt.plot(X_, Y_)
plt.title('Recompensa medida')
plt.xlabel('Numero Episodios')
plt.ylabel('Recompensa')
plt.grid()
plt.show()
env.close()
# Out:
# --------------------------------------------------------------------
# STEP:  1
# Acciones:  [-0.2507076   0.7950055   0.13394925]
# Distancia: 27.096  cm
# --- RECOMPENSA TOTAL: -2.710 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  2
# Acciones:  [0.17196922 0.8026628  0.42158985]
# Distancia: 26.902  cm
# --- RECOMPENSA TOTAL: -2.690 ---
# [ 0.6        -0.05        0.03750008]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  3
# Acciones:  [0.6535302  0.39038357 0.25498456]
# Distancia: 26.817  cm
# --- RECOMPENSA TOTAL: -2.682 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  4
# Acciones:  [0.17891361 0.5985404  0.19754414]
# Distancia: 26.643  cm
# --- RECOMPENSA TOTAL: -2.664 ---
# [ 0.6        -0.05        0.03737452]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  5
# Acciones:  [0.91594976 0.6999714  0.7474981 ]
# Distancia: 26.604  cm
# --- RECOMPENSA TOTAL: -2.660 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  6
# Acciones:  [-0.71391535  0.04798331  0.89732146]
# Distancia: 26.882  cm
# --- RECOMPENSA TOTAL: -2.688 ---
# [ 0.6        -0.05        0.03747376]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  7
# Acciones:  [0.74423575 0.10221219 0.82218033]
# Distancia: 27.109  cm
# --- RECOMPENSA TOTAL: -2.711 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  8
# Acciones:  [ 0.87845     0.28568974 -0.820282  ]
# Distancia: 26.732  cm
# --- RECOMPENSA TOTAL: -2.673 ---
# [ 0.6        -0.05        0.03749656]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  9
# Acciones:  [-0.99338627  0.5357942  -0.57720506]
# Distancia: 26.356  cm
# --- RECOMPENSA TOTAL: -2.634 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  10
# Acciones:  [-0.7665202 -0.1457588  0.2394043]
# Distancia: 26.479  cm
# --- RECOMPENSA TOTAL: -2.648 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  11
# Acciones:  [-0.53590405 -0.7182826   0.3099921 ]
# Distancia: 27.761  cm
# --- RECOMPENSA TOTAL: -2.776 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  12
# Acciones:  [-0.6003373  -0.41996285  0.7499557 ]
# Distancia: 28.167  cm
# --- RECOMPENSA TOTAL: -2.817 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  13
# Acciones:  [0.31902745 0.6054083  0.34882438]
# Distancia: 28.022  cm
# --- RECOMPENSA TOTAL: -2.802 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  14
# Acciones:  [-0.88173836 -0.29159433 -0.5906086 ]
# Distancia: 27.987  cm
# --- RECOMPENSA TOTAL: -2.799 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  15
# Acciones:  [-0.25456807  0.61638796 -0.8805959 ]
# Distancia: 27.487  cm
# --- RECOMPENSA TOTAL: -2.749 ---
# [ 0.6        -0.05        0.03747376]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  16
# Acciones:  [-0.3222835   0.59059805 -0.6223883 ]
# Distancia: 27.078  cm
# --- RECOMPENSA TOTAL: -2.708 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  17
# Acciones:  [ 0.10755108 -0.98340887 -0.77978057]
# Distancia: 27.251  cm
# --- RECOMPENSA TOTAL: -2.725 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  18
# Acciones:  [-0.95528334  0.32048503  0.71904814]
# Distancia: 27.366  cm
# --- RECOMPENSA TOTAL: -2.736 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  19
# Acciones:  [-0.5400012  -0.34159452  0.21482094]
# Distancia: 27.592  cm
# --- RECOMPENSA TOTAL: -2.759 ---
# [ 0.6        -0.05        0.03747902]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  20
# Acciones:  [-0.7923582   0.17077473  0.7209393 ]
# Distancia: 27.777  cm
# --- RECOMPENSA TOTAL: -2.778 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  21
# Acciones:  [-0.9035965   0.26416358  0.0788151 ]
# Distancia: 27.307  cm
# --- RECOMPENSA TOTAL: -2.731 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  22
# Acciones:  [ 0.13734187 -0.4421702   0.21680039]
# Distancia: 27.545  cm
# --- RECOMPENSA TOTAL: -2.754 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  23
# Acciones:  [0.9895686  0.46878043 0.07166874]
# Distancia: 27.358  cm
# --- RECOMPENSA TOTAL: -2.736 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  24
# Acciones:  [-0.00088994 -0.82629544 -0.28100538]
# Distancia: 27.606  cm
# --- RECOMPENSA TOTAL: -2.761 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  25
# Acciones:  [0.37481597 0.73067385 0.33111492]
# Distancia: 27.406  cm
# --- RECOMPENSA TOTAL: -2.741 ---
# [ 0.6        -0.05        0.03739963]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  26
# Acciones:  [-0.25704283  0.23326387  0.04076731]
# Distancia: 27.329  cm
# --- RECOMPENSA TOTAL: -2.733 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  27
# Acciones:  [-0.43083495  0.69251245  0.50687   ]
# Distancia: 27.216  cm
# --- RECOMPENSA TOTAL: -2.722 ---
# [ 0.6        -0.05        0.03750008]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  28
# Acciones:  [-0.34513518  0.27444595  0.21957332]
# Distancia: 27.183  cm
# --- RECOMPENSA TOTAL: -2.718 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  29
# Acciones:  [-0.9703887 -0.9381178 -0.1206086]
# Distancia: 27.541  cm
# --- RECOMPENSA TOTAL: -2.754 ---
# [ 0.6        -0.05        0.03730389]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  30
# Acciones:  [-0.79147846  0.07544012  0.9313133 ]
# Distancia: 27.825  cm
# --- RECOMPENSA TOTAL: -2.783 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  31
# Acciones:  [ 0.9394337  -0.3052746   0.40278062]
# Distancia: 27.598  cm
# --- RECOMPENSA TOTAL: -2.760 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  32
# Acciones:  [-0.10781572  0.5965932   0.14715706]
# Distancia: 27.405  cm
# --- RECOMPENSA TOTAL: -2.741 ---
# [ 0.6        -0.05        0.03750007]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  33
# Acciones:  [ 0.4385481   0.9015848  -0.46747464]
# Distancia: 26.901  cm
# --- RECOMPENSA TOTAL: -2.690 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  34
# Acciones:  [-0.5217579   0.5172691   0.03454551]
# Distancia: 26.711  cm
# --- RECOMPENSA TOTAL: -2.671 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  35
# Acciones:  [-0.7306536   0.667944    0.35303742]
# Distancia: 26.568  cm
# --- RECOMPENSA TOTAL: -2.657 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  36
# Acciones:  [0.5286117  0.20923547 0.327083  ]
# Distancia: 26.579  cm
# --- RECOMPENSA TOTAL: -2.658 ---
# [ 0.6        -0.05        0.03750001]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  37
# Acciones:  [ 0.94922465 -0.6931137   0.55899847]
# Distancia: 27.017  cm
# --- RECOMPENSA TOTAL: -2.702 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  38
# Acciones:  [ 0.45595744  0.95281875 -0.43538433]
# Distancia: 26.507  cm
# --- RECOMPENSA TOTAL: -2.651 ---
# [ 0.6        -0.05        0.03749319]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  39
# Acciones:  [ 0.29512155 -0.999716   -0.85917   ]
# Distancia: 26.633  cm
# --- RECOMPENSA TOTAL: -2.663 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  40
# Acciones:  [ 0.375629   -0.11657247  0.8494399 ]
# Distancia: 26.941  cm
# --- RECOMPENSA TOTAL: -2.694 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  41
# Acciones:  [ 0.14610069 -0.75349844  0.1358795 ]
# Distancia: 27.710  cm
# --- RECOMPENSA TOTAL: -2.771 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  42
# Acciones:  [-0.6282648  -0.22020495  0.09593677]
# Distancia: 27.840  cm
# --- RECOMPENSA TOTAL: -2.784 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  43
# Acciones:  [ 0.6849943 -0.3352775 -0.932524 ]
# Distancia: 27.692  cm
# --- RECOMPENSA TOTAL: -2.769 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  44
# Acciones:  [ 0.69044507 -0.9257914   0.38769543]
# Distancia: 28.173  cm
# --- RECOMPENSA TOTAL: -2.817 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  45
# Acciones:  [ 0.26782584 -0.22743239 -0.98408014]
# Distancia: 27.987  cm
# --- RECOMPENSA TOTAL: -2.799 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  46
# Acciones:  [-0.6644794   0.90298545  0.3301423 ]
# Distancia: 27.714  cm
# --- RECOMPENSA TOTAL: -2.771 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  47
# Acciones:  [0.08354311 0.2579666  0.77645165]
# Distancia: 27.830  cm
# --- RECOMPENSA TOTAL: -2.783 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  48
# Acciones:  [ 0.61870486  0.51457    -0.04244892]
# Distancia: 27.603  cm
# --- RECOMPENSA TOTAL: -2.760 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  49
# Acciones:  [0.08117313 0.09892659 0.26599407]
# Distancia: 27.640  cm
# --- RECOMPENSA TOTAL: -2.764 ---
# [ 0.6        -0.05        0.03749985]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  50
# Acciones:  [ 0.7011381  -0.66570747  0.8227876 ]
# Distancia: 28.164  cm
# --- RECOMPENSA TOTAL: -2.815 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  51
# Acciones:  [-0.5143339 -0.689235   0.4528354]
# Distancia: 27.791  cm
# --- RECOMPENSA TOTAL: -2.779 ---
# [ 0.6        -0.05        0.03749979]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  52
# Acciones:  [0.5473276  0.05192022 0.22966206]
# Distancia: 27.827  cm
# --- RECOMPENSA TOTAL: -2.783 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  53
# Acciones:  [-0.75005275  0.2037823   0.4364752 ]
# Distancia: 27.892  cm
# --- RECOMPENSA TOTAL: -2.791 ---
# [ 0.6        -0.05        0.03749979]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  54
# Acciones:  [0.95868254 0.26333746 0.8843085 ]
# Distancia: 28.038  cm
# --- RECOMPENSA TOTAL: -2.804 ---
# [ 0.6        -0.05        0.03730389]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  55
# Acciones:  [-0.14823961  0.61076534 -0.01256892]
# Distancia: 27.801  cm
# --- RECOMPENSA TOTAL: -2.780 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  56
# Acciones:  [ 0.5983827 -0.6059152  0.3168363]
# Distancia: 28.124  cm
# --- RECOMPENSA TOTAL: -2.812 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  57
# Acciones:  [ 0.8165186  -0.92112213  0.60576004]
# Distancia: 28.667  cm
# --- RECOMPENSA TOTAL: -2.867 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  58
# Acciones:  [-0.36956814  0.6210336  -0.0277998 ]
# Distancia: 28.417  cm
# --- RECOMPENSA TOTAL: -2.842 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  59
# Acciones:  [-0.18344338 -0.48653242  0.99442905]
# Distancia: 28.919  cm
# --- RECOMPENSA TOTAL: -2.892 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  60
# Acciones:  [-0.8133574  -0.11784844  0.16534671]
# Distancia: 29.027  cm
# --- RECOMPENSA TOTAL: -2.903 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  61
# Acciones:  [ 0.93517286  0.6054269  -0.03792026]
# Distancia: 27.102  cm
# --- RECOMPENSA TOTAL: -2.710 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  62
# Acciones:  [0.7981647  0.98274153 0.49071652]
# Distancia: 26.855  cm
# --- RECOMPENSA TOTAL: -2.685 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  63
# Acciones:  [ 0.7651687 -0.5153565 -0.4859766]
# Distancia: 26.912  cm
# --- RECOMPENSA TOTAL: -2.691 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  64
# Acciones:  [ 0.16715777 -0.68875045  0.01593304]
# Distancia: 27.193  cm
# --- RECOMPENSA TOTAL: -2.719 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  65
# Acciones:  [ 0.5219317  -0.04458284  0.69190586]
# Distancia: 27.424  cm
# --- RECOMPENSA TOTAL: -2.742 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  66
# Acciones:  [-0.6908716   0.74037313 -0.14890037]
# Distancia: 27.079  cm
# --- RECOMPENSA TOTAL: -2.708 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  67
# Acciones:  [ 0.16384922 -0.44446442 -0.03339991]
# Distancia: 27.246  cm
# --- RECOMPENSA TOTAL: -2.725 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  68
# Acciones:  [-0.3325585  0.9904148  0.4785933]
# Distancia: 27.000  cm
# --- RECOMPENSA TOTAL: -2.700 ---
# [ 0.6        -0.05        0.03749985]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  69
# Acciones:  [ 0.6881879  -0.83391494 -0.32374108]
# Distancia: 27.234  cm
# --- RECOMPENSA TOTAL: -2.723 ---
# [ 0.6        -0.05        0.03749985]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  70
# Acciones:  [-0.0662041 -0.540908   0.5730853]
# Distancia: 27.622  cm
# --- RECOMPENSA TOTAL: -2.762 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  71
# Acciones:  [0.88358945 0.72325766 0.09023669]
# Distancia: 27.094  cm
# --- RECOMPENSA TOTAL: -2.709 ---
# [ 0.6        -0.05        0.03744866]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  72
# Acciones:  [ 0.71077853 -0.07699832  0.6805334 ]
# Distancia: 27.326  cm
# --- RECOMPENSA TOTAL: -2.733 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  73
# Acciones:  [0.8235098  0.07146325 0.23548752]
# Distancia: 27.369  cm
# --- RECOMPENSA TOTAL: -2.737 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  74
# Acciones:  [ 0.51335335  0.39079416 -0.67326856]
# Distancia: 27.018  cm
# --- RECOMPENSA TOTAL: -2.701 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  75
# Acciones:  [-0.99640715 -0.03815136 -0.6901453 ]
# Distancia: 26.815  cm
# --- RECOMPENSA TOTAL: -2.681 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  76
# Acciones:  [0.08492976 0.55482215 0.8843638 ]
# Distancia: 26.863  cm
# --- RECOMPENSA TOTAL: -2.686 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  77
# Acciones:  [ 0.48618367  0.4403042  -0.10476503]
# Distancia: 26.658  cm
# --- RECOMPENSA TOTAL: -2.666 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  78
# Acciones:  [0.9983353  0.8102887  0.01452735]
# Distancia: 26.355  cm
# --- RECOMPENSA TOTAL: -2.635 ---
# [ 0.6        -0.05        0.03750005]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  79
# Acciones:  [-0.8220395   0.42751333 -0.54188555]
# Distancia: 26.010  cm
# --- RECOMPENSA TOTAL: -2.602 ---
# [ 0.6        -0.05        0.03750008]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  80
# Acciones:  [-0.52399623  0.3299109  -0.19429237]
# Distancia: 25.819  cm
# --- RECOMPENSA TOTAL: -2.582 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  81
# Acciones:  [-0.78317326 -0.26321998 -0.985476  ]
# Distancia: 27.204  cm
# --- RECOMPENSA TOTAL: -2.720 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  82
# Acciones:  [-0.3577023  -0.26228184 -0.21585165]
# Distancia: 27.258  cm
# --- RECOMPENSA TOTAL: -2.726 ---
# [ 0.6        -0.05        0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  83
# Acciones:  [ 0.38790998 -0.27334484  0.57853216]
# Distancia: 27.526  cm
# --- RECOMPENSA TOTAL: -2.753 ---
# [ 0.6        -0.04999999  0.03749961]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  84
# Acciones:  [ 0.8687484   0.7084485  -0.76422423]
# Distancia: 27.002  cm
# --- RECOMPENSA TOTAL: -2.700 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  85
# Acciones:  [ 0.53208536 -0.6228327   0.43679103]
# Distancia: 27.370  cm
# --- RECOMPENSA TOTAL: -2.737 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  86
# Acciones:  [ 0.37855887 -0.0267621   0.6027301 ]
# Distancia: 27.552  cm
# --- RECOMPENSA TOTAL: -2.755 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  87
# Acciones:  [-0.4517924   0.7204628  -0.43840343]
# Distancia: 27.136  cm
# --- RECOMPENSA TOTAL: -2.714 ---
# [ 0.6        -0.04999999  0.03749656]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  88
# Acciones:  [-0.03132208 -0.34147176  0.8221353 ]
# Distancia: 27.516  cm
# --- RECOMPENSA TOTAL: -2.752 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  89
# Acciones:  [0.9958442  0.33244276 0.64046085]
# Distancia: 27.565  cm
# --- RECOMPENSA TOTAL: -2.757 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  90
# Acciones:  [-0.64634365 -0.04823039  0.38165888]
# Distancia: 27.705  cm
# --- RECOMPENSA TOTAL: -2.770 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  91
# Acciones:  [-0.43928266  0.28076842  0.07421439]
# Distancia: 27.287  cm
# --- RECOMPENSA TOTAL: -2.729 ---
# [ 0.6        -0.04999999  0.03750007]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  92
# Acciones:  [ 0.6380951  -0.8318512  -0.13077015]
# Distancia: 27.571  cm
# --- RECOMPENSA TOTAL: -2.757 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  93
# Acciones:  [-0.7887911 -0.9125267 -0.2283228]
# Distancia: 27.890  cm
# --- RECOMPENSA TOTAL: -2.789 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  94
# Acciones:  [-0.9534265  0.6113591  0.58913  ]
# Distancia: 27.841  cm
# --- RECOMPENSA TOTAL: -2.784 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  95
# Acciones:  [-0.24284065  0.15654482  0.5767717 ]
# Distancia: 27.957  cm
# --- RECOMPENSA TOTAL: -2.796 ---
# [ 0.6        -0.04999999  0.03748661]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  96
# Acciones:  [-0.57778937 -0.49436575 -0.10774798]
# Distancia: 28.144  cm
# --- RECOMPENSA TOTAL: -2.814 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  97
# Acciones:  [0.5568723  0.5783876  0.67392755]
# Distancia: 28.094  cm
# --- RECOMPENSA TOTAL: -2.809 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  98
# Acciones:  [-0.55608606  0.0834735   0.04763334]
# Distancia: 28.096  cm
# --- RECOMPENSA TOTAL: -2.810 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  99
# Acciones:  [ 0.06599699 -0.24982564  0.8571715 ]
# Distancia: 28.453  cm
# --- RECOMPENSA TOTAL: -2.845 ---
# [ 0.6        -0.04999999  0.03750009]
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  100
# Acciones:  [-0.2927711  -0.05844629 -0.26051405]
# Distancia: 28.408  cm
# --- RECOMPENSA TOTAL: -2.841 ---
# [ 0.6        -0.04999999  0.0374358 ]
# Reecompensa Actual: 0.000
